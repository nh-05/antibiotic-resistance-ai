# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas numpy matplotlib seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("All libraries installed successfully!")
# Out:
# All libraries installed successfully!

# %%
df1 = pd.read_csv(r"C:\Users\Nupur\Desktop\antibiotic-resistance-prediction\data\raw\primary_dataset.csv", encoding='latin1', errors='ignore')
df2 = pd.read_csv(r"C:\Users\Nupur\Desktop\antibiotic-resistance-prediction\data\raw\secondary_dataset.csv", encoding='latin1', errors='ignore')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df1 = pd.read_csv(
#       2     r"C:\Users\Nupur\Desktop\antibiotic-resistance-prediction\data\raw\primary_dataset.csv",
#       3     encoding='cp1252'
#       4 )
#
# ...
